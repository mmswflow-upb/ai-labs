# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database?resource=download
#
# The dataset consists of several medical predictor variables and one target variable, Outcome. Predictor variables includes the number of pregnancies the patient has had, their BMI, insulin level, age, and so on.

# %% [markdown]
# # Importing pandas and reading our data
#
# Pandas is a Python library used for working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data.

# %%
import pandas as pd

df = pd.read_csv('diabetes.csv')
print(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print(df.tail(7))
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %% [markdown]
# Extracting a list with the names of the columns

# %%
columns = list(df.columns.values)
print(columns)
# Out:
# ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# # Indexing and Slicing

# %%
# accessing the row with index 2
df.iloc[2]
# Out:
# Pregnancies                   8.000
# Glucose                     183.000
# BloodPressure                64.000
# SkinThickness                 0.000
# Insulin                       0.000
# BMI                          23.300
# DiabetesPedigreeFunction      0.672
# Age                          32.000
# Outcome                       1.000
# Name: 2, dtype: float64

# %%
# accessing first 5 rows and first 3 columns
df.iloc[0:5, 0:3]
# Out:
#    Pregnancies  Glucose  BloodPressure
# 0            6      148             72
# 1            1       85             66
# 2            8      183             64
# 3            1       89             66
# 4            0      137             40

# %%
# index of entry and BMI value
for idx, row in df.iterrows():
    print(idx, row["BMI"])
# Out:
# 0 33.6
# 1 26.6
# 2 23.3
# 3 28.1
# 4 43.1
# 5 25.6
# 6 31.0
# 7 35.3
# 8 30.5
# 9 0.0
# 10 37.6
# 11 38.0
# 12 27.1
# 13 30.1
# 14 25.8
# 15 30.0
# 16 45.8
# 17 29.6
# 18 43.3
# 19 34.6
# 20 39.3
# 21 35.4
# 22 39.8
# 23 29.0
# 24 36.6
# 25 31.1
# 26 39.4
# 27 23.2
# 28 22.2
# 29 34.1
# 30 36.0
# 31 31.6
# 32 24.8
# 33 19.9
# 34 27.6
# 35 24.0
# 36 33.2
# 37 32.9
# 38 38.2
# 39 37.1
# 40 34.0
# 41 40.2
# 42 22.7
# 43 45.4
# 44 27.4
# 45 42.0
# 46 29.7
# 47 28.0
# 48 39.1
# 49 0.0
# 50 19.4
# 51 24.2
# 52 24.4
# 53 33.7
# 54 34.7
# 55 23.0
# 56 37.7
# 57 46.8
# 58 40.5
# 59 41.5
# 60 0.0
# 61 32.9
# 62 25.0
# 63 25.4
# 64 32.8
# 65 29.0
# 66 32.5
# 67 42.7
# 68 19.6
# 69 28.9
# 70 32.9
# 71 28.6
# 72 43.4
# 73 35.1
# 74 32.0
# 75 24.7
# 76 32.6
# 77 37.7
# 78 43.2
# 79 25.0
# 80 22.4
# 81 0.0
# 82 29.3
# 83 24.6
# 84 48.8
# 85 32.4
# 86 36.6
# 87 38.5
# 88 37.1
# 89 26.5
# 90 19.1
# 91 32.0
# 92 46.7
# 93 23.8
# 94 24.7
# 95 33.9
# 96 31.6
# 97 20.4
# 98 28.7
# 99 49.7
# 100 39.0
# 101 26.1
# 102 22.5
# 103 26.6
# 104 39.6
# 105 28.7
# 106 22.4
# 107 29.5
# 108 34.3
# 109 37.4
# 110 33.3
# 111 34.0
# 112 31.2
# 113 34.0
# 114 30.5
# 115 31.2
# 116 34.0
# 117 33.7
# 118 28.2
# 119 23.2
# 120 53.2
# 121 34.2
# 122 33.6
# 123 26.8
# 124 33.3
# 125 55.0
# 126 42.9
# 127 33.3
# 128 34.5
# 129 27.9
# 130 29.7
# 131 33.3
# 132 34.5
# 133 38.3
# 134 21.1
# 135 33.8
# 136 30.8
# 137 28.7
# 138 31.2
# 139 36.9
# 140 21.1
# 141 39.5
# 142 32.5
# 143 32.4
# 144 32.8
# 145 0.0
# 146 32.8
# 147 30.5
# 148 33.7
# 149 27.3
# 150 37.4
# 151 21.9
# 152 34.3
# 153 40.6
# 154 47.9
# 155 50.0
# 156 24.6
# 157 25.2
# 158 29.0
# 159 40.9
# 160 29.7
# 161 37.2
# 162 44.2
# 163 29.7
# 164 31.6
# 165 29.9
# 166 32.5
# 167 29.6
# 168 31.9
# 169 28.4
# 170 30.8
# 171 35.4
# 172 28.9
# 173 43.5
# 174 29.7
# 175 32.7
# 176 31.2
# 177 67.1
# 178 45.0
# 179 39.1
# 180 23.2
# 181 34.9
# 182 27.7
# 183 26.8
# 184 27.6
# 185 35.9
# 186 30.1
# 187 32.0
# 188 27.9
# 189 31.6
# 190 22.6
# 191 33.1
# 192 30.4
# 193 52.3
# 194 24.4
# 195 39.4
# 196 24.3
# 197 22.9
# 198 34.8
# 199 30.9
# 200 31.0
# 201 40.1
# 202 27.3
# 203 20.4
# 204 37.7
# 205 23.9
# 206 37.5
# 207 37.7
# 208 33.2
# 209 35.5
# 210 27.7
# 211 42.8
# 212 34.2
# 213 42.6
# 214 34.2
# 215 41.8
# 216 35.8
# 217 30.0
# 218 29.0
# 219 37.8
# 220 34.6
# 221 31.6
# 222 25.2
# 223 28.8
# 224 23.6
# 225 34.6
# 226 35.7
# 227 37.2
# 228 36.7
# 229 45.2
# 230 44.0
# 231 46.2
# 232 25.4
# 233 35.0
# 234 29.7
# 235 43.6
# 236 35.9
# 237 44.1
# 238 30.8
# 239 18.4
# 240 29.2
# 241 33.1
# 242 25.6
# 243 27.1
# 244 38.2
# 245 30.0
# 246 31.2
# 247 52.3
# 248 35.4
# 249 30.1
# 250 31.2
# 251 28.0
# 252 24.4
# 253 35.8
# 254 27.6
# 255 33.6
# 256 30.1
# 257 28.7
# 258 25.9
# 259 33.3
# 260 30.9
# 261 30.0
# 262 32.1
# 263 32.4
# 264 32.0
# 265 33.6
# 266 36.3
# 267 40.0
# 268 25.1
# 269 27.5
# 270 45.6
# 271 25.2
# 272 23.0
# 273 33.2
# 274 34.2
# 275 40.5
# 276 26.5
# 277 27.8
# 278 24.9
# 279 25.3
# 280 37.9
# 281 35.9
# 282 32.4
# 283 30.4
# 284 27.0
# 285 26.0
# 286 38.7
# 287 45.6
# 288 20.8
# 289 36.1
# 290 36.9
# 291 36.6
# 292 43.3
# 293 40.5
# 294 21.9
# 295 35.5
# 296 28.0
# 297 30.7
# 298 36.6
# 299 23.6
# 300 32.3
# 301 31.6
# 302 35.8
# 303 52.9
# 304 21.0
# 305 39.7
# 306 25.5
# 307 24.8
# 308 30.5
# 309 32.9
# 310 26.2
# 311 39.4
# 312 26.6
# 313 29.5
# 314 35.9
# 315 34.1
# 316 19.3
# 317 30.5
# 318 38.1
# 319 23.5
# 320 27.5
# 321 31.6
# 322 27.4
# 323 26.8
# 324 35.7
# 325 25.6
# 326 35.1
# 327 35.1
# 328 45.5
# 329 30.8
# 330 23.1
# 331 32.7
# 332 43.3
# 333 23.6
# 334 23.9
# 335 47.9
# 336 33.8
# 337 31.2
# 338 34.2
# 339 39.9
# 340 25.9
# 341 25.9
# 342 32.0
# 343 34.7
# 344 36.8
# 345 38.5
# 346 28.7
# 347 23.5
# 348 21.8
# 349 41.0
# 350 42.2
# 351 31.2
# 352 34.4
# 353 27.2
# 354 42.7
# 355 30.4
# 356 33.3
# 357 39.9
# 358 35.3
# 359 36.5
# 360 31.2
# 361 29.8
# 362 39.2
# 363 38.5
# 364 34.9
# 365 34.0
# 366 27.6
# 367 21.0
# 368 27.5
# 369 32.8
# 370 38.4
# 371 0.0
# 372 35.8
# 373 34.9
# 374 36.2
# 375 39.2
# 376 25.2
# 377 37.2
# 378 48.3
# 379 43.4
# 380 30.8
# 381 20.0
# 382 25.4
# 383 25.1
# 384 24.3
# 385 22.3
# 386 32.3
# 387 43.3
# 388 32.0
# 389 31.6
# 390 32.0
# 391 45.7
# 392 23.7
# 393 22.1
# 394 32.9
# 395 27.7
# 396 24.7
# 397 34.3
# 398 21.1
# 399 34.9
# 400 32.0
# 401 24.2
# 402 35.0
# 403 31.6
# 404 32.9
# 405 42.1
# 406 28.9
# 407 21.9
# 408 25.9
# 409 42.4
# 410 35.7
# 411 34.4
# 412 42.4
# 413 26.2
# 414 34.6
# 415 35.7
# 416 27.2
# 417 38.5
# 418 18.2
# 419 26.4
# 420 45.3
# 421 26.0
# 422 40.6
# 423 30.8
# 424 42.9
# 425 37.0
# 426 0.0
# 427 34.1
# 428 40.6
# 429 35.0
# 430 22.2
# 431 30.4
# 432 30.0
# 433 25.6
# 434 24.5
# 435 42.4
# 436 37.4
# 437 29.9
# 438 18.2
# 439 36.8
# 440 34.3
# 441 32.2
# 442 33.2
# 443 30.5
# 444 29.7
# 445 59.4
# 446 25.3
# 447 36.5
# 448 33.6
# 449 30.5
# 450 21.2
# 451 28.9
# 452 39.9
# 453 19.6
# 454 37.8
# 455 33.6
# 456 26.7
# 457 30.2
# 458 37.6
# 459 25.9
# 460 20.8
# 461 21.8
# 462 35.3
# 463 27.6
# 464 24.0
# 465 21.8
# 466 27.8
# 467 36.8
# 468 30.0
# 469 46.1
# 470 41.3
# 471 33.2
# 472 38.8
# 473 29.9
# 474 28.9
# 475 27.3
# 476 33.7
# 477 23.8
# 478 25.9
# 479 28.0
# 480 35.5
# 481 35.2
# 482 27.8
# 483 38.2
# 484 44.2
# 485 42.3
# 486 40.7
# 487 46.5
# 488 25.6
# 489 26.1
# 490 36.8
# 491 33.5
# 492 32.8
# 493 28.9
# 494 0.0
# 495 26.6
# 496 26.0
# 497 30.1
# 498 25.1
# 499 29.3
# 500 25.2
# 501 37.2
# 502 39.0
# 503 33.3
# 504 37.3
# 505 33.3
# 506 36.5
# 507 28.6
# 508 30.4
# 509 25.0
# 510 29.7
# 511 22.1
# 512 24.2
# 513 27.3
# 514 25.6
# 515 31.6
# 516 30.3
# 517 37.6
# 518 32.8
# 519 19.6
# 520 25.0
# 521 33.2
# 522 0.0
# 523 34.2
# 524 31.6
# 525 21.8
# 526 18.2
# 527 26.3
# 528 30.8
# 529 24.6
# 530 29.8
# 531 45.3
# 532 41.3
# 533 29.8
# 534 33.3
# 535 32.9
# 536 29.6
# 537 21.7
# 538 36.3
# 539 36.4
# 540 39.4
# 541 32.4
# 542 34.9
# 543 39.5
# 544 32.0
# 545 34.5
# 546 43.6
# 547 33.1
# 548 32.8
# 549 28.5
# 550 27.4
# 551 31.9
# 552 27.8
# 553 29.9
# 554 36.9
# 555 25.5
# 556 38.1
# 557 27.8
# 558 46.2
# 559 30.1
# 560 33.8
# 561 41.3
# 562 37.6
# 563 26.9
# 564 32.4
# 565 26.1
# 566 38.6
# 567 32.0
# 568 31.3
# 569 34.3
# 570 32.5
# 571 22.6
# 572 29.5
# 573 34.7
# 574 30.1
# 575 35.5
# 576 24.0
# 577 42.9
# 578 27.0
# 579 34.7
# 580 42.1
# 581 25.0
# 582 26.5
# 583 38.7
# 584 28.7
# 585 22.5
# 586 34.9
# 587 24.3
# 588 33.3
# 589 21.1
# 590 46.8
# 591 39.4
# 592 34.4
# 593 28.5
# 594 33.6
# 595 32.0
# 596 45.3
# 597 27.8
# 598 36.8
# 599 23.1
# 600 27.1
# 601 23.7
# 602 27.8
# 603 35.2
# 604 28.4
# 605 35.8
# 606 40.0
# 607 19.5
# 608 41.5
# 609 24.0
# 610 30.9
# 611 32.9
# 612 38.2
# 613 32.5
# 614 36.1
# 615 25.8
# 616 28.7
# 617 20.1
# 618 28.2
# 619 32.4
# 620 38.4
# 621 24.2
# 622 40.8
# 623 43.5
# 624 30.8
# 625 37.7
# 626 24.7
# 627 32.4
# 628 34.6
# 629 24.7
# 630 27.4
# 631 34.5
# 632 26.2
# 633 27.5
# 634 25.9
# 635 31.2
# 636 28.8
# 637 31.6
# 638 40.9
# 639 19.5
# 640 29.3
# 641 34.3
# 642 29.5
# 643 28.0
# 644 27.6
# 645 39.4
# 646 23.4
# 647 37.8
# 648 28.3
# 649 26.4
# 650 25.2
# 651 33.8
# 652 34.1
# 653 26.8
# 654 34.2
# 655 38.7
# 656 21.8
# 657 38.9
# 658 39.0
# 659 34.2
# 660 27.7
# 661 42.9
# 662 37.6
# 663 37.9
# 664 33.7
# 665 34.8
# 666 32.5
# 667 27.5
# 668 34.0
# 669 30.9
# 670 33.6
# 671 25.4
# 672 35.5
# 673 57.3
# 674 35.6
# 675 30.9
# 676 24.8
# 677 35.3
# 678 36.0
# 679 24.2
# 680 24.2
# 681 49.6
# 682 44.6
# 683 32.3
# 684 0.0
# 685 33.2
# 686 23.1
# 687 28.3
# 688 24.1
# 689 46.1
# 690 24.6
# 691 42.3
# 692 39.1
# 693 38.5
# 694 23.5
# 695 30.4
# 696 29.9
# 697 25.0
# 698 34.5
# 699 44.5
# 700 35.9
# 701 27.6
# 702 35.0
# 703 38.5
# 704 28.4
# 705 39.8
# 706 0.0
# 707 34.4
# 708 32.8
# 709 38.0
# 710 31.2
# 711 29.6
# 712 41.2
# 713 26.4
# 714 29.5
# 715 33.9
# 716 33.8
# 717 23.1
# 718 35.5
# 719 35.6
# 720 29.3
# 721 38.1
# 722 29.3
# 723 39.1
# 724 32.8
# 725 39.4
# 726 36.1
# 727 32.4
# 728 22.9
# 729 30.1
# 730 28.4
# 731 28.4
# 732 44.5
# 733 29.0
# 734 23.3
# 735 35.4
# 736 27.4
# 737 32.0
# 738 36.6
# 739 39.5
# 740 42.3
# 741 30.8
# 742 28.5
# 743 32.7
# 744 40.6
# 745 30.0
# 746 49.3
# 747 46.3
# 748 36.4
# 749 24.3
# 750 31.2
# 751 39.0
# 752 26.0
# 753 43.3
# 754 32.4
# 755 36.5
# 756 32.0
# 757 36.3
# 758 37.5
# 759 35.5
# 760 28.4
# 761 44.0
# 762 22.5
# 763 32.9
# 764 36.8
# 765 26.2
# 766 30.1
# 767 30.4

# %% [markdown]
# # Filter Data

# %%
# people with a BMI lower than 20
df.loc[df['BMI']<20]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 9              8      125             96              0        0   0.0
# 33             6       92             92              0        0  19.9
# 49             7      105              0              0        0   0.0
# 50             1      103             80             11       82  19.4
# 60             2       84              0              0        0   0.0
# 68             1       95             66             13       38  19.6
# 81             2       74              0              0        0   0.0
# 90             1       80             55              0        0  19.1
# 145            0      102             75             23        0   0.0
# 239            0      104             76              0        0  18.4
# 316            3       99             80             11       64  19.3
# 371            0      118             64             23       89   0.0
# 418            1       83             68              0        0  18.2
# 426            0       94              0              0        0   0.0
# 438            1       97             70             15        0  18.2
# 453            2      119              0              0        0  19.6
# 494            3       80              0              0        0   0.0
# 519            6      129             90              7      326  19.6
# 522            6      114              0              0        0   0.0
# 526            1       97             64             19       82  18.2
# 607            1       92             62             25       41  19.5
# 639            1      100             74             12       46  19.5
# 684            5      136             82              0        0   0.0
# 706           10      115              0              0        0   0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 9                       0.232   54        1
# 33                      0.188   28        0
# 49                      0.305   24        0
# 50                      0.491   22        0
# 60                      0.304   21        0
# 68                      0.334   25        0
# 81                      0.102   22        0
# 90                      0.258   21        0
# 145                     0.572   21        0
# 239                     0.582   27        0
# 316                     0.284   30        0
# 371                     1.731   21        0
# 418                     0.624   27        0
# 426                     0.256   25        0
# 438                     0.147   21        0
# 453                     0.832   72        0
# 494                     0.174   22        0
# 519                     0.582   60        0
# 522                     0.189   26        0
# 526                     0.299   21        0
# 607                     0.482   25        0
# 639                     0.149   28        0
# 684                     0.640   69        0
# 706                     0.261   30        1

# %% [markdown]
# ##### iloc (Index-based Accessor) :
# It's used for label-based selection of rows and columns
# ##### loc (Label-based Accessor):
# It's used for integer-based selection of rows and columns.

# %% [markdown]
# # Condition-based filtering

# %%
df.loc[df['Pregnancies']>12]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 28            13      145             82             19      110  22.2
# 72            13      126             90              0        0  43.4
# 86            13      106             72             54        0  36.6
# 88            15      136             70             32      110  37.1
# 159           17      163             72             41      114  40.9
# 274           13      106             70              0        0  34.2
# 298           14      100             78             25      184  36.6
# 323           13      152             90             33       29  26.8
# 357           13      129              0             30        0  39.9
# 455           14      175             62             30        0  33.6
# 518           13       76             60              0        0  32.8
# 635           13      104             72              0        0  31.2
# 691           13      158            114              0        0  42.3
# 744           13      153             88             37      140  40.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 28                      0.245   57        0
# 72                      0.583   42        1
# 86                      0.178   45        0
# 88                      0.153   43        1
# 159                     0.817   47        1
# 274                     0.251   52        0
# 298                     0.412   46        1
# 323                     0.731   43        1
# 357                     0.569   44        1
# 455                     0.212   38        1
# 518                     0.180   41        0
# 635                     0.465   38        1
# 691                     0.257   44        1
# 744                     1.174   39        0

# %%
filtered_df_neg = df.loc[((df['BloodPressure']>80) | (df['BMI']>=40)) & (df['Outcome']==0) ]
filtered_df_pos = df.loc[((df['BloodPressure']>80) | (df['BMI']>=40)) & (df['Outcome']==1) ]

print("No. of people with diabetes and obesity and high blood presure ", len(filtered_df_pos))
print("No. of people without diabetes and obesity and high blood presure ",len(filtered_df_neg))
# Out:
# No. of people with diabetes and obesity and high blood presure  111
# No. of people without diabetes and obesity and high blood presure  114

# %%
#generate descriptive statistics
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
#changing columns names
df.rename(columns = {'DiabetesPedigreeFunction':'GeneticProbabilityOfDiabetes'}, inplace = True)

# %% [markdown]
# # Sorting

# %%
# printing Glucose and Insulin values sorted ascending by Glucose
print(df[['Glucose', 'Insulin']].sort_values('Glucose'))
# Out:
#      Glucose  Insulin
# 75         0        0
# 349        0        0
# 342        0        0
# 502        0        0
# 182        0       23
# ..       ...      ...
# 408      197        0
# 579      197        0
# 228      197      744
# 561      198      274
# 661      199        0
#
# [768 rows x 2 columns]

# %%
df.sort_values("Age", ascending=False)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 459            9      134             74             33       60  25.9
# 453            2      119              0              0        0  19.6
# 666            4      145             82             18        0  32.5
# 684            5      136             82              0        0   0.0
# 123            5      132             80              0        0  26.8
# ..           ...      ...            ...            ...      ...   ...
# 736            0      126             86             27      120  27.4
# 273            1       71             78             50       45  33.2
# 713            0      134             58             20      291  26.4
# 290            0       78             88             29       40  36.9
# 3              1       89             66             23       94  28.1
#
#      GeneticProbabilityOfDiabetes  Age  Outcome
# 459                         0.460   81        0
# 453                         0.832   72        0
# 666                         0.235   70        1
# 684                         0.640   69        0
# 123                         0.186   69        0
# ..                            ...  ...      ...
# 736                         0.515   21        0
# 273                         0.422   21        0
# 713                         0.352   21        0
# 290                         0.434   21        0
# 3                           0.167   21        0
#
# [768 rows x 9 columns]

# %%
# sorting data ascending by age and descending by Glucose 
# in order to quickly spot the youngest people with the highest level of glucose
df.sort_values(["Age", "Glucose"], ascending=[True, False])
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 220            0      177             60             29      478  34.6
# 580            0      151             90             46        0  42.1
# 413            1      143             74             22       61  26.2
# 94             2      142             82             18       64  24.7
# 486            1      139             62             41      480  40.7
# ..           ...      ...            ...            ...      ...   ...
# 684            5      136             82              0        0   0.0
# 123            5      132             80              0        0  26.8
# 666            4      145             82             18        0  32.5
# 453            2      119              0              0        0  19.6
# 459            9      134             74             33       60  25.9
#
#      GeneticProbabilityOfDiabetes  Age  Outcome
# 220                         1.072   21        1
# 580                         0.371   21        1
# 413                         0.256   21        0
# 94                          0.761   21        0
# 486                         0.536   21        0
# ..                            ...  ...      ...
# 684                         0.640   69        0
# 123                         0.186   69        0
# 666                         0.235   70        1
# 453                         0.832   72        0
# 459                         0.460   81        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ##### Groupby
# A groupby operation involves some combination of splitting the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups.

# %%
mean_values_age = df.groupby(['Age']).mean()
#mean_values_age = mean_values_age.drop(columns=['Outcome'])
mean_values_age = mean_values_age.drop('Outcome', axis=1)
mean_values_age.sort_values('GeneticProbabilityOfDiabetes', ascending=False)
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Age
# 56      8.000000   98.333333      76.333333      32.333333   69.000000
# 72      2.000000  119.000000       0.000000       0.000000    0.000000
# 33      4.058824  122.882353      65.647059      21.705882   85.588235
# 57      8.800000  137.800000      76.800000       9.600000   78.000000
# 44      7.250000  124.375000      61.750000       4.625000   32.250000
# 34      5.857143  131.857143      74.000000      18.714286  148.071429
# 51      8.625000  147.625000      84.500000      21.875000  129.375000
# 32      4.437500  116.312500      70.062500      18.187500   35.812500
# 61      5.500000  144.000000      76.000000      16.500000   95.000000
# 49      7.600000  153.000000      81.400000      21.600000   55.200000
# 39      7.416667  126.750000      72.666667      26.083333   72.416667
# 67      4.000000  132.333333      72.666667       0.000000    0.000000
# 25      1.770833  110.083333      59.666667      23.958333   82.895833
# 31      3.875000  126.958333      64.375000      20.000000  111.166667
# 68      8.000000   91.000000      82.000000       0.000000    0.000000
# 62      3.750000  139.500000      71.500000      29.000000    0.000000
# 58      7.142857  135.142857      78.285714      19.285714  167.857143
# 53      5.400000  158.000000      79.000000      21.200000  183.000000
# 52      4.625000  133.000000      81.500000      13.375000   94.500000
# 45      7.333333  131.200000      83.066667      20.600000   31.133333
# 36      5.187500  132.437500      69.125000      19.187500   65.812500
# 27      2.562500  115.281250      73.500000      18.375000   63.125000
# 50      6.750000  138.250000      78.250000      16.000000   26.375000
# 54      7.000000  140.333333      89.333333       8.833333   61.000000
# 81      9.000000  134.000000      74.000000      33.000000   60.000000
# 28      3.028571  119.914286      68.314286      23.628571   94.600000
# 48      8.800000  107.600000      78.400000      23.400000   52.000000
# 35      5.000000  121.400000      75.600000      22.600000   75.000000
# 43      7.769231  133.000000      78.461538      27.846154  125.153846
# 23      1.578947  111.578947      64.315789      22.368421  118.026316
# 60      6.000000  146.400000      80.000000      20.000000  164.200000
# 21      1.079365  108.317460      65.936508      19.349206   73.634921
# 22      1.555556  108.208333      63.722222      20.486111   74.486111
# 46      6.384615  105.923077      76.000000      24.153846  112.307692
# 37      5.263158  130.157895      75.947368      18.315789   59.263158
# 38      6.875000  121.125000      71.125000      19.625000   33.500000
# 26      1.969697  118.212121      64.181818      23.666667   90.878788
# 69      5.000000  134.000000      81.000000       0.000000    0.000000
# 64      8.000000  120.000000      78.000000       0.000000    0.000000
# 29      3.310345  127.379310      68.241379      21.000000   88.793103
# 66      5.000000  157.000000      86.000000       0.000000    0.000000
# 41      6.500000  129.090909      67.590909      17.409091   38.818182
# 24      1.891304  117.891304      64.956522      25.934783   88.021739
# 42      6.888889  109.555556      73.388889      19.222222   61.277778
# 40      6.230769  130.923077      69.230769      24.230769   72.307692
# 30      3.619048  122.285714      64.857143      18.904762   82.666667
# 47      8.333333  137.000000      78.333333      14.500000   49.166667
# 65      3.333333  137.000000      78.666667      12.333333    0.000000
# 59      2.333333  173.333333      74.000000      16.666667  282.000000
# 63      5.500000  133.250000      78.000000      23.500000   45.000000
# 70      4.000000  145.000000      82.000000      18.000000    0.000000
# 55      5.500000  140.750000      70.250000      16.250000   83.750000
#
#            BMI  GeneticProbabilityOfDiabetes
# Age
# 56   31.700000                      0.936667
# 72   19.600000                      0.832000
# 33   32.335294                      0.734176
# 57   29.700000                      0.704000
# 44   34.162500                      0.668375
# 34   31.164286                      0.649857
# 51   33.975000                      0.615250
# 32   32.318750                      0.613250
# 61   30.000000                      0.613000
# 49   32.020000                      0.612000
# 39   31.983333                      0.605917
# 67   28.766667                      0.602000
# 25   31.943750                      0.600500
# 31   34.016667                      0.589583
# 68   35.600000                      0.587000
# 62   28.950000                      0.565500
# 58   32.428571                      0.554714
# 53   30.500000                      0.550600
# 52   33.475000                      0.505375
# 45   34.960000                      0.496467
# 36   31.718750                      0.472875
# 27   31.950000                      0.471750
# 50   31.225000                      0.470125
# 54   30.800000                      0.465500
# 81   25.900000                      0.460000
# 28   33.642857                      0.459629
# 48   29.980000                      0.456800
# 35   33.780000                      0.454000
# 43   36.892308                      0.450846
# 23   31.502632                      0.438579
# 60   28.740000                      0.436800
# 21   27.817460                      0.433825
# 22   29.509722                      0.430625
# 46   34.523077                      0.426846
# 37   32.078947                      0.414632
# 38   35.568750                      0.413938
# 26   34.915152                      0.413455
# 69   13.400000                      0.413000
# 64   25.000000                      0.409000
# 29   33.541379                      0.408897
# 66   30.375000                      0.408500
# 41   35.259091                      0.396273
# 24   32.569565                      0.393565
# 42   34.983333                      0.388000
# 40   33.538462                      0.376077
# 30   30.033333                      0.367238
# 47   34.566667                      0.355333
# 65   31.600000                      0.259000
# 59   26.966667                      0.252667
# 63   30.775000                      0.249250
# 70   32.500000                      0.235000
# 55   27.025000                      0.226500

# %%
# saving the Outcome values
target = df["Outcome"]
target
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
# eliminating columns
df.drop(columns=["Outcome"])
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      GeneticProbabilityOfDiabetes  Age
# 0                           0.627   50
# 1                           0.351   31
# 2                           0.672   32
# 3                           0.167   21
# 4                           2.288   33
# ..                            ...  ...
# 763                         0.171   63
# 764                         0.340   27
# 765                         0.245   30
# 766                         0.349   47
# 767                         0.315   23
#
# [768 rows x 8 columns]

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      GeneticProbabilityOfDiabetes  Age  Outcome
# 0                           0.627   50        1
# 1                           0.351   31        0
# 2                           0.672   32        1
# 3                           0.167   21        0
# 4                           2.288   33        1
# ..                            ...  ...      ...
# 763                         0.171   63        0
# 764                         0.340   27        0
# 765                         0.245   30        0
# 766                         0.349   47        1
# 767                         0.315   23        0
#
# [768 rows x 9 columns]

# %%
# we have to make the attribution in order to apply the change
df=df.drop(columns=["Outcome"])

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      GeneticProbabilityOfDiabetes  Age
# 0                           0.627   50
# 1                           0.351   31
# 2                           0.672   32
# 3                           0.167   21
# 4                           2.288   33
# ..                            ...  ...
# 763                         0.171   63
# 764                         0.340   27
# 765                         0.245   30
# 766                         0.349   47
# 767                         0.315   23
#
# [768 rows x 8 columns]

# %%
df=df.join(target)
#df = pd.concat([df, target], axis=1)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      GeneticProbabilityOfDiabetes  Age  Outcome
# 0                           0.627   50        1
# 1                           0.351   31        0
# 2                           0.672   32        1
# 3                           0.167   21        0
# 4                           2.288   33        1
# ..                            ...  ...      ...
# 763                         0.171   63        0
# 764                         0.340   27        0
# 765                         0.245   30        0
# 766                         0.349   47        1
# 767                         0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# # Changing values based on conditions

# %%
df.loc[(df['Glucose']>150) & (df['Outcome']==0) & (df['BMI']>=40)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 153            1      153             82             42      485  40.6
# 247            0      165             90             33      680  52.3
# 335            0      165             76             43      255  47.9
# 469            6      154             78             41      140  46.1
# 487            0      173             78             32      265  46.5
# 608            0      152             82             39      272  41.5
# 622            6      183             94              0        0  40.8
# 744           13      153             88             37      140  40.6
#
#      GeneticProbabilityOfDiabetes  Age  Outcome
# 153                         0.687   23        0
# 247                         0.427   23        0
# 335                         0.259   26        0
# 469                         0.571   27        0
# 487                         1.159   58        0
# 608                         0.270   27        0
# 622                         1.461   45        0
# 744                         1.174   39        0

# %%
# If the glucose and BMI values are high and that person is not marked as sick there is most likely a problem. 
# We extract the indexes of those rows and modify the Outcome value to 1
rows_to_modify = list(df.loc[(df['Glucose']>150) & (df['Outcome']==0) & (df['BMI']>=40)].index.values) 
rows_to_modify
# Out:
# [np.int64(153),
#  np.int64(247),
#  np.int64(335),
#  np.int64(469),
#  np.int64(487),
#  np.int64(608),
#  np.int64(622),
#  np.int64(744)]

# %%
df.loc[(df['Glucose']>150) & (df['Outcome']==0) & (df['BMI']>=40), 'Outcome'] = 1
df.loc[rows_to_modify]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 153            1      153             82             42      485  40.6
# 247            0      165             90             33      680  52.3
# 335            0      165             76             43      255  47.9
# 469            6      154             78             41      140  46.1
# 487            0      173             78             32      265  46.5
# 608            0      152             82             39      272  41.5
# 622            6      183             94              0        0  40.8
# 744           13      153             88             37      140  40.6
#
#      GeneticProbabilityOfDiabetes  Age  Outcome
# 153                         0.687   23        1
# 247                         0.427   23        1
# 335                         0.259   26        1
# 469                         0.571   27        1
# 487                         1.159   58        1
# 608                         0.270   27        1
# 622                         1.461   45        1
# 744                         1.174   39        1

# %%
selection_condition = df['Age'].isin([21,23])
df[selection_condition]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 55             1       73             50             10        0  23.0
# 60             2       84              0              0        0   0.0
# 73             4      129             86             20      270  35.1
# 90             1       80             55              0        0  19.1
# ..           ...      ...            ...            ...      ...   ...
# 713            0      134             58             20      291  26.4
# 721            1      114             66             36      200  38.1
# 736            0      126             86             27      120  27.4
# 738            2       99             60             17      160  36.6
# 767            1       93             70             31        0  30.4
#
#      GeneticProbabilityOfDiabetes  Age  Outcome
# 3                           0.167   21        0
# 55                          0.248   21        0
# 60                          0.304   21        0
# 73                          0.231   23        0
# 90                          0.258   21        0
# ..                            ...  ...      ...
# 713                         0.352   21        0
# 721                         0.289   21        0
# 736                         0.515   21        0
# 738                         0.453   21        0
# 767                         0.315   23        0
#
# [101 rows x 9 columns]

# %% [markdown]
# # Saving Files

# %%
df.to_csv("diabetesIndexed.csv")

# %%
df.to_csv("diabetesNotIndexed.csv", index=False)

# %%
df.to_excel("diabetesExcel.xlsx", index=False)

# %%
df2 = pd.read_excel("diabetesExcel.xlsx", index_col=False)

# %%
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      GeneticProbabilityOfDiabetes  Age  Outcome
# 0                           0.627   50        1
# 1                           0.351   31        0
# 2                           0.672   32        1
# 3                           0.167   21        0
# 4                           2.288   33        1
# ..                            ...  ...      ...
# 763                         0.171   63        0
# 764                         0.340   27        0
# 765                         0.245   30        0
# 766                         0.349   47        1
# 767                         0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Bar plots

# %% [markdown]
# It's important to check for Data Imbalance. For classification tasks, check the distribution of the target variable to identify if the classes are imbalanced using .value_counts() or bar plots.

# %%
df = pd.read_csv('diabetes.csv')

# %%
diabetes_counts = df['Outcome'].value_counts()
plt.figure(figsize=(6, 4))
diabetes_counts.plot(kind='bar', color=['blue', 'red'])
plt.title('Data Imbalance')
plt.ylabel('Number of People')
plt.xlabel('Outcome')

plt.show()
# or sns.countplot(x='Outcome', data= df)

# %% [markdown]
# Method of dealing with imbalanced classes: https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# # Box plots
# We can use boxplots to detect outliers in numerical data

# %%
plt.figure(figsize=(12,12))
for i, col in enumerate(columns):
    plt.subplot(3,3, i+1)# sublot on which our boxplot is drawn for identifying outlier
    sns.boxplot(x=col, data = df)
plt.show()

# %% [markdown]
# # Histograms
# We can plot histograms to understand the distribution of continuous variables. This also helps in detecting outliers.

# %%
plt.figure(figsize=(12,12))
for i, col in enumerate(columns):
    plt.subplot(3,3, i+1)
    sns.histplot(x=col, data = df, kde = True)
plt.show()

# %% [markdown]
# # Heatmaps
# We can use heatmaps to visualize the correlation between variables, which can reveal clusters or correlations.

# %%
plt.figure(figsize= (12,12))
sns.heatmap(df.corr(),cmap='coolwarm', annot = True) 
plt.show()

# %% [markdown]
# Correlation coefficients:
#
# 1: as one variable increases, the other variable increases proportionally
#
# -1: as one variable increases, the other decreases proportionally
#
# 0: no linear relationship between the variables
#
# We can observe that the highest positive correlation (0.54) is between Age and Pregnancies, suggesting that as age increases, the number of pregnancies tends to increase as well.
#
# Glucose and Outcome show a  positive correlation of 0.47, indicating that higher glucose levels are associated with a higher likelihood of diabetes.
#
# We can also observe a corelation between Insulin and SkinThickness implying that higher insulin levels tend to be associated with thicker skin, which is indeed something mentioned in specialized literature: https://pubmed.ncbi.nlm.nih.gov/2721339/

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %% [markdown]
# # Scatterplots
# A scatter plot identifies a possible relationship between changes observed in two different sets of variables.

# %%
plt.figure(figsize=(20, 12))
sns.scatterplot(data=df, x='Glucose', y='BMI', hue='Outcome', style='Outcome', s=100)
plt.title('Scatter Plot of Glucose vs BMI')
plt.xlabel('Glucose Level')
plt.ylabel('BMI')
plt.legend(title='Outcome', loc='upper left', labels=['No Diabetes', 'Diabetes'])
plt.grid(True)
plt.show()

# %% [markdown]
# # Missing values
#
# In datasets, these missing entries might appear as the letter "0", "NA", "NaN", "NULL", "Not Applicable", or "None”. In this case we observe that missing data is marked with 0. No one can have a BMI of 0.

# %%
missing_values = (df[['SkinThickness', 'BloodPressure', 'BMI']] == 0).sum()
print("Number of missing values:")
print(missing_values)
# Out:
# Number of missing values:
# SkinThickness    227
# BloodPressure     35
# BMI               11
# dtype: int64

# %%
mean_skin_thickness = df['SkinThickness'][df['SkinThickness'] != 0].mean()
df['SkinThickness'] = df['SkinThickness'].replace(0, mean_skin_thickness)
missing_values = (df[['SkinThickness', 'BloodPressure', 'BMI']] == 0).sum()
print("Number of missing values:")
print(missing_values)
# Out:
# Number of missing values:
# SkinThickness     0
# BloodPressure    35
# BMI              11
# dtype: int64

# %% [markdown]
# Mean Imputation: useful when the data follows a normal distribution, the mean is a good representation of the central tendency.
#
# Median Imputation: it's less sensitive to outliers than the mean.
#
# Mode Imputation: useful for categorical data or discrete numerical data. The mode is the value that appears most frequently in a dataset. In the context of mode imputation, it is used to replace missing values with the most common value in a given column.
#
# Forward Fill: It replaces missing values with the last observed non-missing value in the column.
#
# Backward Fill: It replaces missing values with the next observed non-missing value in the column.

# %% [markdown]
# # Categorical Features
# Stroke dataset: https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset/data

# %%
stroke_df = pd.read_csv("stroke-data.csv", index_col=0)

# %%
stroke_df
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
# ...       ...   ...           ...            ...          ...            ...
# 18234  Female  80.0             1              0          Yes        Private
# 44873  Female  81.0             0              0          Yes  Self-employed
# 19723  Female  35.0             0              0          Yes  Self-employed
# 37544    Male  51.0             0              0          Yes        Private
# 44679  Female  44.0             0              0          Yes       Govt_job
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# id
# 9046           Urban             228.69  36.6  formerly smoked       1
# 51676          Rural             202.21   NaN     never smoked       1
# 31112          Rural             105.92  32.5     never smoked       1
# 60182          Urban             171.23  34.4           smokes       1
# 1665           Rural             174.12  24.0     never smoked       1
# ...              ...                ...   ...              ...     ...
# 18234          Urban              83.75   NaN     never smoked       0
# 44873          Urban             125.20  40.0     never smoked       0
# 19723          Rural              82.99  30.6     never smoked       0
# 37544          Rural             166.29  25.6  formerly smoked       0
# 44679          Urban              85.28  26.2          Unknown       0
#
# [5110 rows x 11 columns]

# %% [markdown]
# In the previous dataset we only had numerical data, but in this dataset we also home categorical features. Since machine learning algorithms can only process numerical values we need to convert these categorical features into appropriate numerical representations. In order to do this we can use:
#
# Label Encoder: Encode target labels with value between 0 and n_classes-1. ![image.png](attachment:image.png)
#
# One-Hot Encoder: Encode categorical features as a one-hot numeric array.
# ![image-2.png](attachment:image-2.png)

# %%
stroke_df.head()
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# id
# 9046           Urban             228.69  36.6  formerly smoked       1
# 51676          Rural             202.21   NaN     never smoked       1
# 31112          Rural             105.92  32.5     never smoked       1
# 60182          Urban             171.23  34.4           smokes       1
# 1665           Rural             174.12  24.0     never smoked       1

# %%
stroke_one_hot_df = pd.get_dummies(stroke_df)
stroke_one_hot_df.head()
# Out:
#         age  hypertension  heart_disease  avg_glucose_level   bmi  stroke  \
# id
# 9046   67.0             0              1             228.69  36.6       1
# 51676  61.0             0              0             202.21   NaN       1
# 31112  80.0             0              1             105.92  32.5       1
# 60182  49.0             0              0             171.23  34.4       1
# 1665   79.0             1              0             174.12  24.0       1
#
#        gender_Female  gender_Male  gender_Other  ever_married_No  ...  \
# id                                                                ...
# 9046           False         True         False            False  ...
# 51676           True        False         False            False  ...
# 31112          False         True         False            False  ...
# 60182           True        False         False            False  ...
# 1665            True        False         False            False  ...
#
#        work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# id
# 9046                    False               True                    False
# 51676                   False              False                     True
# 31112                   False               True                    False
# 60182                   False               True                    False
# 1665                    False              False                     True
#
#        work_type_children  Residence_type_Rural  Residence_type_Urban  \
# id
# 9046                False                 False                  True
# 51676               False                  True                 False
# 31112               False                  True                 False
# 60182               False                 False                  True
# 1665                False                  True                 False
#
#        smoking_status_Unknown  smoking_status_formerly smoked  \
# id
# 9046                    False                            True
# 51676                   False                           False
# 31112                   False                           False
# 60182                   False                           False
# 1665                    False                           False
#
#        smoking_status_never smoked  smoking_status_smokes
# id
# 9046                         False                  False
# 51676                         True                  False
# 31112                         True                  False
# 60182                        False                   True
# 1665                          True                  False
#
# [5 rows x 22 columns]

# %%
categorical_columns = stroke_df.select_dtypes(include=['object', 'category']).columns.tolist()
categorical_columns
# Out:
# ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
label_mappings = {}

for column in categorical_columns:  
    stroke_df[column] = label_encoder.fit_transform(stroke_df[column])
    label_mappings[column] = dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))

print(label_mappings)
stroke_df.head()
# Out:
# {'gender': {'Female': 0, 'Male': 1, 'Other': 2}, 'ever_married': {'No': 0, 'Yes': 1}, 'work_type': {'Govt_job': 0, 'Never_worked': 1, 'Private': 2, 'Self-employed': 3, 'children': 4}, 'Residence_type': {'Rural': 0, 'Urban': 1}, 'smoking_status': {'Unknown': 0, 'formerly smoked': 1, 'never smoked': 2, 'smokes': 3}}
#        gender   age  hypertension  heart_disease  ever_married  work_type  \
# id
# 9046        1  67.0             0              1             1          2
# 51676       0  61.0             0              0             1          3
# 31112       1  80.0             0              1             1          2
# 60182       0  49.0             0              0             1          2
# 1665        0  79.0             1              0             1          3
#
#        Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# id
# 9046                1             228.69  36.6               1       1
# 51676               0             202.21   NaN               2       1
# 31112               0             105.92  32.5               2       1
# 60182               1             171.23  34.4               3       1
# 1665                0             174.12  24.0               2       1

# %% [markdown]
# # Exercises

# %% [markdown]
# 1. Determine the target value (the value that we want to predict/classify depending on task) and create a plot to see if the dataset we are using has class imbalance or not.

# %%
target_col = "stroke"

print("Target column:", target_col)
print(stroke_df[target_col].value_counts())
print(stroke_df[target_col].value_counts(normalize=True))

stroke_df[target_col].value_counts().plot(kind="bar")
plt.xticks([0, 1], ["No stroke (0)", "Stroke (1)"], rotation=0)
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("Class distribution for stroke")
plt.show()

# The dataset is very imbalanced
# Most people are in class 0 no stroke and only a small part are class 1 stroke
# A model that always predicts no stroke would still get high accuracy
# but it would almost never catch the actual stroke cases
# Out:
# Target column: stroke
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64
# stroke
# 0    0.951272
# 1    0.048728
# Name: proportion, dtype: float64

# %% [markdown]
# 2. Using any graphical representation of your choice, determine if there are correlations between the features. Choose 2 correlations that you identified as relevant and explain them.

# %%
plt.figure(figsize=(10, 8))
corr_matrix = stroke_df.corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f")
plt.title("Correlation matrix for stroke dataset")
plt.show()

# From the heatmap age clearly stands out as the feature most related to stroke
# Heart disease hypertension and avg_glucose_level also have a smaller positive link to stroke
# This fits the idea that older age heart problems high blood pressure and higher glucose
# all go together with a higher chance of stroke

# %% [markdown]
# 3. Count and display how many entries are missing for the BMI feature, and fill in the missing values. Justify your choice of method.

# %%
missing_bmi = stroke_df["bmi"].isna().sum()
print("Number of missing BMI values:", missing_bmi)

bmi_median = stroke_df["bmi"].median()
print("BMI median:", bmi_median)

stroke_df["bmi"].fillna(bmi_median, inplace=True)

#Check again
print("Missing BMI after imputation:", stroke_df["bmi"].isna().sum())

# There are 201 missing BMI values in the dataset
# We fill them with the median BMI 28.1 because the median is less sensitive to extreme values
# so it gives a more typical BMI for this group
# After filling there are no missing BMI values left so this feature is ready to use
# Out:
# Number of missing BMI values: 201
# BMI median: 28.1
# Missing BMI after imputation: 0
# /tmp/ipykernel_7514/3542801444.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   stroke_df["bmi"].fillna(bmi_median, inplace=True)

# %% [markdown]
# 4. Determine the number of people who had both heart disease and high blood pressure, and categorize them as either smokers or non-smokers.

# %%
both_hd_hyp = stroke_df[(stroke_df["heart_disease"] == 1) &
                        (stroke_df["hypertension"] == 1)]

print("Total with both heart disease and hypertension:", len(both_hd_hyp))

smoker_codes = [1, 3]   
non_smoker_codes = [2]  

smokers = both_hd_hyp[both_hd_hyp["smoking_status"].isin(smoker_codes)]
non_smokers = both_hd_hyp[both_hd_hyp["smoking_status"].isin(non_smoker_codes)]
unknown_smoking = both_hd_hyp[both_hd_hyp["smoking_status"] == 0]

print("Smokers:", len(smokers))
print("Non-smokers:", len(non_smokers))
print("Unknown smoking status:", len(unknown_smoking))

# There are 64 people who have both heart disease and high blood pressure
# Out of these 36 have a history of smoking 23 never smoked and 5 have unknown smoking status
# This shows that many of the highest risk patients combine several risk factors
# like heart disease hypertension and smoking at the same time
# Out:
# Total with both heart disease and hypertension: 64
# Smokers: 36
# Non-smokers: 23
# Unknown smoking status: 5

# %% [markdown]
# 5. Sort the DataFrame by age in ascending order and by glucose level in descending order. Then, rearrange the column names in alphabetical order, keeping the stroke column as the last one.

# %%
stroke_sorted = stroke_df.sort_values(
    by=["age", "avg_glucose_level"],
    ascending=[True, False]
)

cols = list(stroke_sorted.columns)

cols_without_stroke = [c for c in cols if c != "stroke"]
cols_without_stroke.sort()
final_cols = cols_without_stroke + ["stroke"]

stroke_sorted = stroke_sorted[final_cols]

stroke_sorted.head()

# Now the rows are ordered from the youngest patients to the oldest
# and within the same age the ones with higher average glucose come first
# This makes it easier to spot high glucose cases in each age group
# The columns are in alphabetical order and stroke is kept as the last column
# so the target variable is clearly separated from the other features
# Out:
#        Residence_type   age  avg_glucose_level   bmi  ever_married  gender  \
# id
# 47350               1  0.08             139.67  14.1             0       0
# 29955               0  0.08              70.33  16.9             0       1
# 22877               1  0.16             114.71  17.4             0       1
# 8247                1  0.16             109.52  13.9             0       1
# 41500               0  0.16              69.79  13.0             0       1
#
#        heart_disease  hypertension  smoking_status  work_type  stroke
# id
# 47350              0             0               0          4       0
# 29955              0             0               0          4       0
# 22877              0             0               0          4       0
# 8247               0             0               0          4       0
# 41500              0             0               0          4       0

# %% [markdown]
# Save the final csv file

# %%
stroke_sorted.to_csv("processed_stroke_data.csv")
